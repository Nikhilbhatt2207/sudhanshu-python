# %%
sudh=10

# %%
sudh
# Out:
# 10

# %%
sudh-2
# Out:
# 8

# %%
# there is inbuilt funtion already available in python to find the type of the data or type of variable and that function is type()

# %%
type(sudh)
# Out:
# int

# %% [markdown]
# variable is created to store a data coz without storing data it is not possible to carry out operations on them as the data may be the smallest or largest in the size for ex= i try to read a pdf which is large in size and try to find my name and how many time alphabet"s" is there in pdf

# %%
a=34.09

# %%
type(a)
# Out:
# float

# %%
b="this is my first class of python and today date is 14"

# %%
type(b)
# Out:
# str

# %%
c='hdksdk kjdkkdfn kjsdklwdejwkl'

# %%
c
# Out:
# 'hdksdk kjdkkdfn kjsdklwdejwkl'

# %%
type(c)
# Out:
# str

# %%
d=True

# %%
type(d)
# Out:
# bool

# %%
d
# Out:
# True

# %%
e=False

# %%
type(d)
# Out:
# bool

# %%
True-False
# Out:
# 1

# %%
True-True
# Out:
# 0

# %%
False-True
# Out:
# -1

# %%
False/True
# Out:
# 0.0

# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
n=5+7j

# %%
type(n)
# Out:
# complex

# %%
n.conjugate
# Out:
# <function complex.conjugate()>

# %%
n.imag
# Out:
# 7.0

# %%
n.real
# Out:
# 5.0

# %%
n+n
# Out:
# (10+14j)

# %%
b
# Out:
# 'this is my first class of python and today date is 14'

# %% [markdown]
# to find the number of fuctions available on that particular type of variable press "." after that variable as examble from above complex variable

# %% [markdown]
# to find the defination or what the function does go to that particular function and type shift+tab example funtion type()

# %%
l=[3,4,5,6,"sudh",True,3+4j]

# %%
type(l)
# Out:
# list

# %%
l[1]
# Out:
# 4

# %% [markdown]
# in list you call its internal data by calling index number using [] and wrting the index number uu want to call as seen from above example

# %%
t=(3,4,5,6,"sudh",True,3+4j)

# %%
t
# Out:
# (3, 4, 5, 6, 'sudh', True, (3+4j))

# %%
type(t)
# Out:
# tuple

# %%
d={"a":"sudh","b":"kumar","c":2345}

# %%
d
# Out:
# {'a': 'sudh', 'b': 'kumar', 'c': 2345}

# %%
type(d)
# Out:
# dict

# %%
s={45,65,7,642,"sudh"}

# %%
s
# Out:
# {45, 642, 65, 7, 'sudh'}

# %%
type(s)
# Out:
# set
